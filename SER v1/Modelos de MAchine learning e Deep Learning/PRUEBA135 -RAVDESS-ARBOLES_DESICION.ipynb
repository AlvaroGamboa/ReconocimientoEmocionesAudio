# %% [markdown]
# # **CARGA DE TRAIN Y TEST**

# %%
import numpy as np
import pandas as pd

# %%
x_train=pd.read_excel('05-x_train-RAVDESS-SINRUIDOSEXTREMOS-dato_audioopensmile.xlsx',index_col=0)
x_test=pd.read_excel('05-x_test-RAVDESS-SINRUIDOSEXTREMOS-dato_audioopensmile.xlsx',index_col=0)
y_train=pd.read_excel('05-y_train-RAVDESS-SINRUIDOSEXTREMOS-dato_audioopensmile.xlsx',index_col=0)
y_test=pd.read_excel('05-y_test-RAVDESS-SINRUIDOSEXTREMOS-dato_audioopensmile.xlsx',index_col=0)

# %%
x_train
# Out:
#      Loudness_sma3  alphaRatio_sma3  hammarbergIndex_sma3  slope0-500_sma3  \
# 90        0.215409        -9.348865             16.670317         0.065444
# 531       0.085797       -16.513533             26.244503         0.049183
# 492       0.563135        -7.162978             15.494725         0.144593
# 200       0.413840       -11.153063             22.222227         0.145823
# 402       0.328647       -13.787154             24.670168         0.032593
# ..             ...              ...                   ...              ...
# 277       0.145556       -14.881295             25.483837         0.064668
# 9         0.586896        -9.136888             16.632467         0.052081
# 359       0.863225        -6.990873             17.166529         0.099146
# 192       0.231148       -10.927219             17.977736         0.070894
# 559       0.261700       -10.309346             21.844738         0.116191
#
#      slope500-1500_sma3  spectralFlux_sma3  mfcc1_sma3  mfcc2_sma3  \
# 90            -0.013415           0.053069   26.594482    0.511910
# 531           -0.013191           0.017293   26.614561   17.562231
# 492           -0.006577           0.217526   10.974022  -18.723562
# 200           -0.009489           0.214562   25.001774   -6.906032
# 402           -0.011155           0.123292   30.038246    3.431727
# ..                  ...                ...         ...         ...
# 277           -0.020475           0.038528   33.007126    5.084921
# 9             -0.018852           0.265093   20.435955   -4.069752
# 359           -0.003013           0.532472   11.550458  -25.511089
# 192           -0.019315           0.069673   24.386042    2.696081
# 559           -0.014706           0.075430   24.863323   -3.855231
#
#      mfcc3_sma3  mfcc4_sma3  ...  logRelF0-H1-A3_sma3nz  F1frequency_sma3nz  \
# 90    20.186705    4.693410  ...              18.192881          808.811157
# 531   11.433095    3.895259  ...              20.207161          585.776611
# 492  -10.943933  -24.795145  ...              10.098401          866.738464
# 200   -0.636149   -8.209146  ...              14.959212          636.357361
# 402   16.535887    3.519480  ...              21.928129          645.730103
# ..          ...         ...  ...                    ...                 ...
# 277    7.073613    1.603030  ...              18.878904          456.535004
# 9     12.990916   -5.807331  ...              11.841673          619.968567
# 359   -9.151129  -25.327696  ...              10.981806          768.142334
# 192   11.380140    0.781675  ...              14.637096          467.993958
# 559   -3.367654   -4.606955  ...              17.926329          520.844788
#
#      F1bandwidth_sma3nz  F1amplitudeLogRelF0_sma3nz  F2frequency_sma3nz  \
# 90          1118.669678                  -14.980642         1804.398438
# 531         1169.516602                  -80.624176         1567.780762
# 492         1100.495117                  -21.313683         1836.603882
# 200         1078.503418                  -23.257929         1650.696655
# 402         1156.745850                  -33.592209         1619.783081
# ..                  ...                         ...                 ...
# 277         1237.919922                  -34.235203         1412.699097
# 9           1075.356812                  -29.814981         1649.425415
# 359         1088.997070                  -17.285652         1760.218628
# 192         1094.441650                  -50.053112         1464.412109
# 559         1286.038330                  -19.501268         1515.020874
#
#      F2bandwidth_sma3nz  F2amplitudeLogRelF0_sma3nz  F3frequency_sma3nz  \
# 90           885.325623                  -20.047995         2839.987305
# 531          918.880615                  -89.359978         2664.712891
# 492          917.546326                  -25.640020         2849.613037
# 200          797.134460                  -33.546780         2619.937500
# 402         1010.574829                  -43.730709         2594.508057
# ..                  ...                         ...                 ...
# 277          955.805847                  -43.698612         2439.599609
# 9            678.257996                  -38.348324         2710.641113
# 359         1018.889648                  -23.720716         2737.804688
# 192          784.086914                  -59.347012         2402.289795
# 559          897.622070                  -27.098932         2556.563477
#
#      F3bandwidth_sma3nz  F3amplitudeLogRelF0_sma3nz
# 90           792.004211                  -23.334564
# 531          792.905823                  -94.987045
# 492          692.944092                  -28.145546
# 200          774.869690                  -39.106663
# 402          838.815063                  -49.116562
# ..                  ...                         ...
# 277          735.044373                  -51.136097
# 9            722.857422                  -39.496727
# 359          886.291992                  -28.635784
# 192          741.353394                  -61.321152
# 559          812.100769                  -35.004784
#
# [489 rows x 25 columns]

# %% [markdown]
# # **SELECCION DE CARACTERISTICAS**

# %%
#prueba 03 Eliminando ['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz']
x_train=x_train.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)
x_test=x_test.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)

# %% [markdown]
# # **NORMALIZACION DE CARACTERISTICAS**

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train_std = sc.fit_transform(x_train)
#para trasnformar los datos de testing
x_test_std = sc.transform(x_test)

# %%
x_train_std
# Out:
# array([[-0.65379796,  0.10281262, -0.4682503 , ...,  1.06778724,
#          0.1084606 ,  1.31225206],
#        [-0.97641108, -1.52942526,  1.60008068, ..., -0.15393326,
#          0.11696015, -1.72608704],
#        [ 0.21171181,  0.60079624, -0.72221572, ...,  1.13488177,
#         -0.8253861 ,  1.10824805],
#        ...,
#        [ 0.95865409,  0.64000465, -0.36105261, ...,  0.35554068,
#          0.99731812,  1.08746007],
#        [-0.61462443, -0.25676448, -0.18580595, ..., -1.98310881,
#         -0.36902821, -0.29852446],
#        [-0.5385785 , -0.11600206,  0.64959048, ..., -0.90777035,
#          0.29791226,  0.81739015]])

# %% [markdown]
# # **MODELO DE MARCHINE LEARNING**

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion="entropy", max_depth = 5)
clf.fit(x_train_std, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5)

# %%
#para generar 300 un nuevo modelo y guardar el que tiene mayor accuracy
from sklearn import metrics
mayor=0
for i in range(300):

  sc = StandardScaler()
  x_train_std = sc.fit_transform(x_train)
  #para trasnformar los datos de testing
  x_test_std = sc.transform(x_test)

  clf = DecisionTreeClassifier(criterion="entropy", max_depth = 5)
  clf.fit(x_train_std, y_train)
  y_predict = clf.predict(x_test_std)
  predicion = metrics.accuracy_score(y_test, y_predict)
  if predicion >mayor:
    mayor= predicion
    modelo = clf
  print(f" prueba :{i} PRECISION ====  {metrics.accuracy_score(y_test, y_predict)} ")
clf= modelo
# Out:
#  prueba :0 PRECISION ====  0.5365853658536586
#  prueba :1 PRECISION ====  0.5447154471544715
#  prueba :2 PRECISION ====  0.5365853658536586
#  prueba :3 PRECISION ====  0.5365853658536586
#  prueba :4 PRECISION ====  0.5528455284552846
#  prueba :5 PRECISION ====  0.5365853658536586
#  prueba :6 PRECISION ====  0.5365853658536586
#  prueba :7 PRECISION ====  0.5528455284552846
#  prueba :8 PRECISION ====  0.5528455284552846
#  prueba :9 PRECISION ====  0.5447154471544715
#  prueba :10 PRECISION ====  0.5365853658536586
#  prueba :11 PRECISION ====  0.5447154471544715
#  prueba :12 PRECISION ====  0.5447154471544715
#  prueba :274 PRECISION ====  0.5365853658536586
#  prueba :275 PRECISION ====  0.5447154471544715
#  prueba :276 PRECISION ====  0.5447154471544715
#  prueba :277 PRECISION ====  0.5528455284552846
#  prueba :278 PRECISION ====  0.5447154471544715
#  prueba :279 PRECISION ====  0.5447154471544715
#  prueba :280 PRECISION ====  0.5528455284552846
#  prueba :281 PRECISION ====  0.5365853658536586
#  prueba :282 PRECISION ====  0.5365853658536586
#  prueba :283 PRECISION ====  0.5528455284552846
#  prueba :284 PRECISION ====  0.5365853658536586
#  prueba :285 PRECISION ====  0.5447154471544715
#  prueba :286 PRECISION ====  0.5528455284552846
#  prueba :287 PRECISION ====  0.5528455284552846
#  prueba :288 PRECISION ====  0.5447154471544715
#  prueba :289 PRECISION ====  0.5528455284552846
#  prueba :290 PRECISION ====  0.5365853658536586
#  prueba :291 PRECISION ====  0.5528455284552846
#  prueba :292 PRECISION ====  0.5528455284552846
#  prueba :293 PRECISION ====  0.5447154471544715
#  prueba :294 PRECISION ====  0.5365853658536586
#  prueba :295 PRECISION ====  0.5447154471544715
#  prueba :296 PRECISION ====  0.5528455284552846
#  prueba :297 PRECISION ====  0.5365853658536586
#  prueba :298 PRECISION ====  0.5528455284552846
#  prueba :299 PRECISION ====  0.5447154471544715

# %%
y_predict = clf.predict(x_test_std)
y_predict
# Out:
# array([3, 0, 1, 0, 2, 2, 0, 1, 0, 3, 1, 2, 1, 1, 1, 1, 3, 1, 0, 0, 2, 1,
#        2, 1, 3, 0, 1, 2, 1, 0, 1, 0, 1, 0, 1, 1, 1, 3, 0, 2, 0, 1, 1, 1,
#        0, 3, 1, 1, 2, 1, 1, 1, 0, 1, 1, 0, 1, 2, 0, 0, 1, 1, 1, 2, 1, 0,
#        1, 1, 1, 2, 1, 2, 2, 1, 3, 1, 0, 0, 1, 3, 1, 1, 2, 2, 1, 2, 1, 3,
#        1, 1, 3, 3, 1, 0, 0, 1, 2, 1, 1, 1, 2, 1, 1, 1, 3, 1, 0, 0, 2, 2,
#        0, 0, 1, 3, 1, 0, 1, 1, 0, 3, 0, 3, 2])

# %% [markdown]
# # **EVALUACION**

# %%
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.54      0.62        39
#            1       0.43      0.83      0.57        30
#            2       0.38      0.73      0.50        11
#            3       0.93      0.33      0.48        43
#
#     accuracy                           0.55       123
#    macro avg       0.62      0.61      0.54       123
# weighted avg       0.70      0.55      0.55       123

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    Esta función imprime y marca la matriz de confusión.
    Se puede aplicar Normalización seteando la variable `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Matriz de confusión, sin normalización')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta True')
    plt.xlabel('Etiqueta predecida')

# %%
# Computar la matriz de confusión
cnf_matrix = confusion_matrix(y_test, y_predict, labels=[0,1,2,3])
np.set_printoptions(precision=2)

print (classification_report(y_test, y_predict))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['angry:0','happy:1','Neutral:2','sad:3',],normalize= False,  title='Matriz de confusión')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.54      0.62        39
#            1       0.43      0.83      0.57        30
#            2       0.38      0.73      0.50        11
#            3       0.93      0.33      0.48        43
#
#     accuracy                           0.55       123
#    macro avg       0.62      0.61      0.54       123
# weighted avg       0.70      0.55      0.55       123
#
# Matriz de confusión, sin normalización
# [[21 17  1  0]
#  [ 4 25  0  1]
#  [ 1  2  8  0]
#  [ 3 14 12 14]]
