# %% [markdown]
# # **CARGA DE TRAIN Y TEST**

# %%
import numpy as np
import pandas as pd

# %%
x_train=pd.read_excel('06-x_train-RAVDESS-SINRUIDOGENERAL-dato_audioopensmile.xlsx',index_col=0)
x_test=pd.read_excel('06-x_test-RAVDESS-SINRUIDOGENERAL-dato_audioopensmile.xlsx',index_col=0)
y_train=pd.read_excel('06-y_train-RAVDESS-SINRUIDOGENERAL-dato_audioopensmile.xlsx',index_col=0)
y_test=pd.read_excel('06-y_test-RAVDESS-SINRUIDOGENERAL-dato_audioopensmile.xlsx',index_col=0)

# %%
x_train
# Out:
#      Loudness_sma3  alphaRatio_sma3  hammarbergIndex_sma3  slope0-500_sma3  \
# 90        0.686283       -13.365475             21.805387         0.117362
# 531       0.133466       -14.529531             22.736057         0.112346
# 492       0.183029       -13.627054             22.315231         0.124793
# 200       0.523292       -10.153658             22.308111         0.144648
# 402       2.682242        12.360218             12.542377         0.056838
# ..             ...              ...                   ...              ...
# 277       0.283596       -13.299419             25.118744         0.044590
# 9         0.093795       -11.796680             20.428913         0.037718
# 359       0.446532       -12.687489             20.756443         0.060692
# 192       0.286837       -11.549992             18.774134         0.085880
# 559       1.201126        -6.732415             13.394994         0.098924
#
#      slope500-1500_sma3  spectralFlux_sma3  mfcc1_sma3  mfcc2_sma3  \
# 90            -0.021745           0.322117   29.065540   -9.949350
# 531           -0.023369           0.032919   18.559624   10.611594
# 492           -0.027166           0.045454   23.496080   10.312009
# 200           -0.011178           0.282330   27.493036  -11.956691
# 402            0.007022           1.791305  -14.205788  -36.585232
# ..                  ...                ...         ...         ...
# 277           -0.014351           0.099824   35.764061   -1.885084
# 9             -0.018227           0.017418   26.071024    7.912013
# 359           -0.019685           0.167253   23.574137    9.460127
# 192           -0.021647           0.091296   28.928902   -1.466480
# 559           -0.020966           0.615772   25.728386  -11.314625
#
#      mfcc3_sma3  mfcc4_sma3  ...  logRelF0-H1-A3_sma3nz  F1frequency_sma3nz  \
# 90     4.122379  -19.894485  ...              18.396330          504.795868
# 531    4.591365  -19.379351  ...              19.466185          589.415955
# 492    3.196333   -7.855220  ...              22.666872          625.758667
# 200   -4.424508  -13.302747  ...              17.931633          652.066223
# 402  -26.608820  -18.001987  ...              15.256498          994.205811
# ..          ...         ...  ...                    ...                 ...
# 277   16.389793   -2.305246  ...              23.867781          538.415894
# 9     15.630949   -2.663414  ...              11.617766          601.591003
# 359    8.270959   -5.526428  ...              16.390491          498.381622
# 192    7.663468   -3.639192  ...              15.776812          423.518951
# 559   25.247391  -11.122494  ...               9.370111          731.009521
#
#      F1bandwidth_sma3nz  F1amplitudeLogRelF0_sma3nz  F2frequency_sma3nz  \
# 90          1264.451050                  -11.238270         1474.455933
# 531         1160.766357                  -61.190533         1689.937988
# 492         1158.075317                  -37.016109         1695.405518
# 200         1089.980835                   -5.874428         1658.170044
# 402          910.718018                    7.747478         2060.611328
# ..                  ...                         ...                 ...
# 277         1340.674194                   -3.173047         1518.291382
# 9           1185.978882                  -94.244774         1640.789185
# 359         1125.148682                  -29.589844         1494.545288
# 192         1167.467285                  -26.100771         1417.748047
# 559         1012.624084                   -5.958165         1834.142090
#
#      F2bandwidth_sma3nz  F2amplitudeLogRelF0_sma3nz  F3frequency_sma3nz  \
# 90           905.831726                  -22.195908         2472.879883
# 531          812.833435                  -72.793419         2699.937988
# 492          800.553040                  -50.555527         2700.184814
# 200          807.325623                  -15.494067         2639.942871
# 402          854.444702                    2.405577         3003.860840
# ..                  ...                         ...                 ...
# 277         1065.604126                  -14.805732         2579.634033
# 9            834.311829                 -101.348862         2609.575928
# 359          802.199646                  -40.953072         2501.636230
# 192          833.290955                  -35.354836         2365.710693
# 559          634.649658                  -15.266139         2785.055908
#
#      F3bandwidth_sma3nz  F3amplitudeLogRelF0_sma3nz
# 90           701.091248                  -27.536795
# 531          869.368103                  -76.697639
# 492          785.643494                  -55.593662
# 200          858.077698                  -22.693600
# 402          842.517822                    2.130888
# ..                  ...                         ...
# 277          810.602112                  -22.540342
# 9            870.959167                 -104.110413
# 359          619.473389                  -44.815826
# 192          752.638855                  -39.228447
# 559          837.501770                  -11.375785
#
# [489 rows x 25 columns]

# %% [markdown]
# # **SELECCION DE CARACTERISTICAS**

# %%
#prueba 03 Eliminando ['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz']
x_train=x_train.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)
x_test=x_test.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)

# %% [markdown]
# # **NORMALIZACION DE CARACTERISTICAS**

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train_std = sc.fit_transform(x_train)
#para trasnformar los datos de testing
x_test_std = sc.transform(x_test)

# %%
x_train_std
# Out:
# array([[ 0.0703118 , -0.66880798,  0.40607192, ..., -1.18126693,
#         -0.60868486,  0.22867699],
#        [-0.85783443, -0.89335889,  0.59077473, ...,  0.13238371,
#          0.68338356, -1.92285126],
#        [-0.77462166, -0.71926769,  0.50725667, ...,  0.13381173,
#          0.04052675, -0.99923403],
#        ...,
#        [-0.33221569, -0.53802181,  0.19789605, ..., -1.01489632,
#         -1.23536556, -0.5275412 ],
#        [-0.60033417, -0.31859421, -0.1955175 , ..., -1.80129709,
#         -0.21289047, -0.2830091 ],
#        [ 0.93470275,  0.61073517, -1.26307365, ...,  0.62483568,
#          0.43870653,  0.93596486]])

# %% [markdown]
# # **MODELO DE MARCHINE LEARNING**

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=300)
clf.fit(x_train_std, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(n_estimators=300)

# %%
#para generar 200 un nuevo modelo y guardar el que tiene mayor accuracy
from sklearn import metrics
mayor=0

for i in range(200):

  sc = StandardScaler()
  x_train_std = sc.fit_transform(x_train)
  #para trasnformar los datos de testing
  x_test_std = sc.transform(x_test)

  clf=RandomForestClassifier(n_estimators=300)
  clf.fit(x_train_std, y_train)
  y_predict = clf.predict(x_test_std)
  predicion = metrics.accuracy_score(y_test, y_predict)
  if predicion >mayor:
    mayor= predicion
    modelo = clf
  print(f" prueba :{i} PRECISION ====  {metrics.accuracy_score(y_test, y_predict)} ")
clf= modelo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :0 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :1 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :2 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :3 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :4 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :5 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :6 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :7 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :8 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :9 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :10 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :11 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :12 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :13 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :14 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :15 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :16 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :17 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :18 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :19 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :20 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :21 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :22 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :23 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :24 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :25 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :26 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :27 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :28 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :29 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :30 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :31 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :32 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :33 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :34 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :35 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :36 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :37 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :38 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :39 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :40 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :41 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :42 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :43 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :44 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :45 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :46 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :47 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :48 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :49 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :50 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :51 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :52 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :53 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :54 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :55 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :56 PRECISION ====  0.6422764227642277
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :57 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :58 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :59 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :60 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :61 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :62 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :63 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :64 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :65 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :66 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :67 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :68 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :69 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :70 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :71 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :72 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :73 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :74 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :75 PRECISION ====  0.6422764227642277
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :76 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :77 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :78 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :79 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :80 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :81 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :82 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :83 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :84 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :85 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :86 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :87 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :88 PRECISION ====  0.6422764227642277
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :89 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :90 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :91 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :92 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :93 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :94 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :95 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :96 PRECISION ====  0.6504065040650406
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :97 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :98 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :99 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :100 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :101 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :102 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :103 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :104 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :105 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :106 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :107 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :108 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :109 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :110 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :111 PRECISION ====  0.5691056910569106
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :112 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :113 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :114 PRECISION ====  0.5691056910569106
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :115 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :116 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :117 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :118 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :119 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :120 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :121 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :122 PRECISION ====  0.6422764227642277
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :123 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :124 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :125 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :126 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :127 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :128 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :129 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :130 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :131 PRECISION ====  0.5772357723577236
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :132 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :133 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :134 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :135 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :136 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :137 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :138 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :139 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :140 PRECISION ====  0.5609756097560976
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :141 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :142 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :143 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :144 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :145 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :146 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :147 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :148 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :149 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :150 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :151 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :152 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :153 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :154 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :155 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :156 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :157 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :158 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :159 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :160 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :161 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :162 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :163 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :164 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :165 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :166 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :167 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :168 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :169 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :170 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :171 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :172 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :173 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :174 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :175 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :176 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :177 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :178 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :179 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :180 PRECISION ====  0.6260162601626016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :181 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :182 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :183 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :184 PRECISION ====  0.5853658536585366
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :185 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :186 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :187 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :188 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :189 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :190 PRECISION ====  0.6341463414634146
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :191 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :192 PRECISION ====  0.6016260162601627
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :193 PRECISION ====  0.5609756097560976
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :194 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :195 PRECISION ====  0.6097560975609756
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :196 PRECISION ====  0.6178861788617886
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :197 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :198 PRECISION ====  0.5934959349593496
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :199 PRECISION ====  0.6097560975609756

# %%
y_predict = clf.predict(x_test_std)
y_predict
# Out:
# array([0, 2, 0, 1, 2, 3, 3, 1, 3, 3, 3, 0, 1, 1, 0, 0, 3, 1, 0, 1, 0, 0,
#        3, 0, 1, 1, 2, 3, 1, 0, 1, 0, 2, 2, 0, 3, 1, 3, 3, 0, 0, 1, 3, 1,
#        0, 0, 1, 3, 2, 1, 3, 0, 0, 3, 3, 0, 1, 1, 2, 1, 1, 1, 0, 0, 0, 1,
#        1, 1, 0, 2, 1, 1, 3, 0, 1, 3, 3, 3, 3, 3, 0, 0, 2, 3, 0, 0, 0, 1,
#        1, 0, 0, 1, 0, 3, 3, 3, 2, 0, 0, 1, 0, 1, 3, 0, 3, 0, 3, 3, 0, 1,
#        0, 0, 1, 3, 1, 3, 1, 3, 0, 3, 3, 1, 3])

# %% [markdown]
# # **EVALUACION**

# %%
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72        39
#            1       0.47      0.49      0.48        35
#            2       0.80      0.47      0.59        17
#            3       0.72      0.81      0.76        32
#
#     accuracy                           0.65       123
#    macro avg       0.68      0.63      0.64       123
# weighted avg       0.66      0.65      0.65       123

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    Esta función imprime y marca la matriz de confusión.
    Se puede aplicar Normalización seteando la variable `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Matriz de confusión, sin normalización')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta True')
    plt.xlabel('Etiqueta predecida')

# %%
# Computar la matriz de confusión
cnf_matrix = confusion_matrix(y_test, y_predict, labels=[0,1,2,3])
np.set_printoptions(precision=2)

print (classification_report(y_test, y_predict))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['angry:0','happy:1','Neutral:2','sad:3',],normalize= False,  title='Matriz de confusión')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.74      0.72        39
#            1       0.47      0.49      0.48        35
#            2       0.80      0.47      0.59        17
#            3       0.72      0.81      0.76        32
#
#     accuracy                           0.65       123
#    macro avg       0.68      0.63      0.64       123
# weighted avg       0.66      0.65      0.65       123
#
# Matriz de confusión, sin normalización
# [[29 10  0  0]
#  [10 17  1  7]
#  [ 1  5  8  3]
#  [ 1  4  1 26]]
