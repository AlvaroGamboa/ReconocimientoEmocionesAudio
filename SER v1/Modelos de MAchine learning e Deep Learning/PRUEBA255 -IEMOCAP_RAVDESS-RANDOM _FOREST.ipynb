# %% [markdown]
# # **CARGA DE TRAIN Y TEST**

# %%
import numpy as np
import pandas as pd

# %%
x_train=pd.read_excel('08-x_train-IEMOCAP_RAVDESS-SINRUIDOEXTREMO-dato_audioopensmile.xlsx',index_col=0)
x_test=pd.read_excel('08-x_test-IEMOCAP_RAVDESS-SINRUIDOEXTREMO-dato_audioopensmile.xlsx',index_col=0)
y_train=pd.read_excel('08-y_train-IEMOCAP_RAVDESS-SINRUIDOEXTREMO-dato_audioopensmile.xlsx',index_col=0)
y_test=pd.read_excel('08-y_test-IEMOCAP_RAVDESS-SINRUIDOEXTREMO-dato_audioopensmile.xlsx',index_col=0)

# %%
x_train
# Out:
#       Loudness_sma3  alphaRatio_sma3  hammarbergIndex_sma3  slope0-500_sma3  \
# 1985       0.447231       -11.604174             21.490801         0.038471
# 1042       0.130339       -13.971890             21.746626        -0.008703
# 891        0.139997       -11.060719             19.946362         0.013390
# 2368       0.095909       -16.350796             26.492107         0.050327
# 2074       0.207064       -11.585189             21.526285         0.010757
# ...             ...              ...                   ...              ...
# 763        0.705233       -10.934845             20.832191         0.032123
# 835        0.152195       -18.900702             25.110928         0.022950
# 1653       0.393978        -9.785304             16.518093         0.046550
# 2607       0.741847        -5.888695             14.027196         0.097359
# 2732       0.354416       -10.899975             19.630547         0.129606
#
#       slope500-1500_sma3  spectralFlux_sma3  mfcc1_sma3  mfcc2_sma3  \
# 1985           -0.012293           0.144106   28.098433  -10.617289
# 1042           -0.013396           0.040137   26.985868   -0.558767
# 891            -0.012108           0.033937   28.312416   -1.162980
# 2368           -0.012176           0.020982   31.657263    8.626080
# 2074           -0.012373           0.056513   32.527023   -5.295373
# ...                  ...                ...         ...         ...
# 763            -0.014040           0.296190   29.328007   -1.673850
# 835            -0.015909           0.045306   29.697210    8.321755
# 1653           -0.023924           0.109758   33.946442  -13.765141
# 2607           -0.012075           0.363559   10.607660   -2.755274
# 2732           -0.020561           0.150145   13.209335   -2.340224
#
#       mfcc3_sma3  mfcc4_sma3  ...  logRelF0-H1-A3_sma3nz  F1frequency_sma3nz  \
# 1985   20.953278  -24.534029  ...              12.985882          522.951538
# 1042   16.637335   -7.789950  ...               4.312049          534.695984
# 891    18.854933   -9.202812  ...              11.208985          424.967590
# 2368   13.638150   10.352103  ...              18.536983          618.059448
# 2074   17.996965   -9.502275  ...              13.354664          470.853241
# ...          ...         ...  ...                    ...                 ...
# 763    16.420149  -14.524237  ...              16.508810          505.037109
# 835    32.056129   -5.489374  ...              19.120968          389.106476
# 1653   20.133909  -17.838442  ...              13.534039          511.860992
# 2607    8.066515  -23.939238  ...               9.214839          579.768677
# 2732   -1.890497  -26.710400  ...              15.968453          635.421936
#
#       F1bandwidth_sma3nz  F1amplitudeLogRelF0_sma3nz  F2frequency_sma3nz  \
# 1985         1133.895142                  -30.807289         1609.510742
# 1042         1314.701050                 -144.111618         1540.003052
# 891          1218.401245                  -80.970428         1408.374634
# 2368         1312.831299                  -63.806530         1599.830322
# 2074         1216.402954                  -88.774590         1420.680054
# ...                  ...                         ...                 ...
# 763          1200.989746                  -46.904739         1440.581177
# 835          1101.953979                   -1.563233         1522.205444
# 1653         1263.066162                  -32.984955         1529.643555
# 2607         1010.931824                  -59.240295         1587.181641
# 2732         1206.145020                  -43.503883         1741.678711
#
#       F2bandwidth_sma3nz  F2amplitudeLogRelF0_sma3nz  F3frequency_sma3nz  \
# 1985          823.846802                  -40.938789         2569.409912
# 1042         1082.633667                 -148.148804         2535.023926
# 891           879.948120                  -87.788223         2442.695801
# 2368         1080.459595                  -72.440758         2624.917480
# 2074          937.014832                  -93.780037         2443.020996
# ...                  ...                         ...                 ...
# 763           908.405945                  -51.135757         2567.123535
# 835           943.652405                  -28.814367         2340.425293
# 1653          944.030762                  -40.274120         2502.376953
# 2607          830.136902                  -65.184532         2653.903320
# 2732          779.466125                  -55.726257         2752.028076
#
#       F3bandwidth_sma3nz  F3amplitudeLogRelF0_sma3nz
# 1985          798.029785                  -42.804501
# 1042          834.851501                 -149.138763
# 891           782.476257                  -92.060295
# 2368          875.469421                  -78.148018
# 2074          830.303101                  -98.739037
# ...                  ...                         ...
# 763           652.237549                  -58.575439
# 835           807.583984                  -25.708191
# 1653          833.882385                  -42.945442
# 2607          608.805115                  -67.819084
# 2732          847.854309                  -57.085651
#
# [2313 rows x 25 columns]

# %% [markdown]
# # **SELECCION DE CARACTERISTICAS**

# %%
#prueba 03 Eliminando ['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz']
x_train=x_train.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)
x_test=x_test.drop(['slope500-1500_sma3','mfcc3_sma3','logRelF0-H1-A3_sma3nz'] , axis =1)

# %% [markdown]
# # **NORMALIZACION DE CARACTERISTICAS**

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

x_train_std = sc.fit_transform(x_train)
#para trasnformar los datos de testing
x_test_std = sc.transform(x_test)

# %%
x_train_std
# Out:
# array([[-1.14802026e-02, -2.17794669e-01,  3.56421445e-01, ...,
#         -6.38066018e-02, -3.59005396e-01,  6.88939794e-01],
#        [-7.97804190e-01, -8.15343450e-01,  4.15773507e-01, ...,
#         -3.12687895e-01, -6.52748343e-02, -2.33068659e+00],
#        [-7.73839962e-01, -8.06410416e-02, -1.89241301e-03, ...,
#         -9.80946845e-01, -4.83077464e-01, -7.09801241e-01],
#        ...,
#        [-1.43620156e-01,  2.41239668e-01, -7.97259427e-01, ...,
#         -5.48982433e-01, -7.30055725e-02,  6.84937406e-01],
#        [ 7.19569573e-01,  1.22464028e+00, -1.37515392e+00, ...,
#          5.47745688e-01, -1.86846976e+00, -2.14116453e-02],
#        [-2.41787209e-01, -4.00736011e-02, -7.51622914e-02, ...,
#          1.25795990e+00,  3.84498795e-02,  2.83390927e-01]])

# %% [markdown]
# # **MODELO DE MARCHINE LEARNING**

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=300)
clf.fit(x_train_std, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(n_estimators=300)

# %%
#para generar 200 un nuevo modelo y guardar el que tiene mayor accuracy
from sklearn import metrics
mayor=0

for i in range(200):

  sc = StandardScaler()
  x_train_std = sc.fit_transform(x_train)
  #para trasnformar los datos de testing
  x_test_std = sc.transform(x_test)

  clf=RandomForestClassifier(n_estimators=300)
  clf.fit(x_train_std, y_train)
  y_predict = clf.predict(x_test_std)
  predicion = metrics.accuracy_score(y_test, y_predict)
  if predicion >mayor:
    mayor= predicion
    modelo = clf
  print(f" prueba :{i} PRECISION ====  {metrics.accuracy_score(y_test, y_predict)} ")
clf= modelo
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :0 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :1 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :2 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :3 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :4 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :5 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :6 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :7 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :8 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :9 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :10 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :11 PRECISION ====  0.690846286701209
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :12 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :13 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :14 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :15 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :16 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :17 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :18 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :19 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :20 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :21 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :22 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :23 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :24 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :25 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :26 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :27 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :28 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :29 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :30 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :31 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :32 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :33 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :34 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :35 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :36 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :37 PRECISION ====  0.6580310880829016
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :38 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :39 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :40 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :41 PRECISION ====  0.6614853195164075
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :42 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :43 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :44 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :45 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :46 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :47 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :48 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :49 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :50 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :51 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :52 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :53 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :54 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :55 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :56 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :57 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :58 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :59 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :60 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :61 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :62 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :63 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :64 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :65 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :66 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :67 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :68 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :69 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :70 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :71 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :72 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :73 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :74 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :75 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :76 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :77 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :78 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :79 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :80 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :81 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :82 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :83 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :84 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :85 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :86 PRECISION ====  0.6839378238341969
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :87 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :88 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :89 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :90 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :91 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :92 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :93 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :94 PRECISION ====  0.689119170984456
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :95 PRECISION ====  0.6839378238341969
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :96 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :97 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :98 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :99 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :100 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :101 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :102 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :103 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :104 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :105 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :106 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :107 PRECISION ====  0.687392055267703
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :108 PRECISION ====  0.6839378238341969
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :109 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :110 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :111 PRECISION ====  0.687392055267703
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :112 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :113 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :114 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :115 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :116 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :117 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :118 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :119 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :120 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :121 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :122 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :123 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :124 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :125 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :126 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :127 PRECISION ====  0.687392055267703
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :128 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :129 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :130 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :131 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :132 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :133 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :134 PRECISION ====  0.696027633851468
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :135 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :136 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :137 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :138 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :139 PRECISION ====  0.6822107081174439
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :140 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :141 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :142 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :143 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :144 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :145 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :146 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :147 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :148 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :149 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :150 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :151 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :152 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :153 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :154 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :155 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :156 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :157 PRECISION ====  0.689119170984456
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :158 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :159 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :160 PRECISION ====  0.6683937823834197
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :161 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :162 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :163 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :164 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :165 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :166 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :167 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :168 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :169 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :170 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :171 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :172 PRECISION ====  0.6856649395509499
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :173 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :174 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :175 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :176 PRECISION ====  0.689119170984456
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :177 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :178 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :179 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :180 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :181 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :182 PRECISION ====  0.6632124352331606
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :183 PRECISION ====  0.6735751295336787
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :184 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :185 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :186 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :187 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :188 PRECISION ====  0.6753022452504318
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :189 PRECISION ====  0.6701208981001727
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :190 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :191 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :192 PRECISION ====  0.6666666666666666
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :193 PRECISION ====  0.6649395509499136
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :194 PRECISION ====  0.6787564766839378
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :195 PRECISION ====  0.6804835924006909
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :196 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :197 PRECISION ====  0.6770293609671848
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :198 PRECISION ====  0.6718480138169257
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   del sys.path[0]
#  prueba :199 PRECISION ====  0.6770293609671848

# %%
y_predict = clf.predict(x_test_std)
y_predict
# Out:
# array([2, 3, 1, 2, 3, 0, 2, 1, 1, 0, 2, 2, 2, 3, 0, 1, 3, 3, 2, 2, 0, 2,
#        3, 2, 3, 1, 2, 2, 2, 0, 2, 2, 3, 2, 3, 0, 2, 1, 2, 3, 1, 2, 2, 3,
#        2, 2, 3, 2, 0, 2, 2, 0, 2, 3, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2,
#        2, 2, 0, 2, 3, 2, 3, 2, 3, 0, 1, 3, 0, 1, 2, 3, 2, 3, 2, 3, 0, 2,
#        2, 3, 2, 2, 3, 0, 3, 1, 2, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 2, 3,
#        2, 0, 1, 2, 2, 3, 2, 2, 2, 3, 2, 2, 3, 0, 3, 3, 0, 0, 3, 3, 1, 3,
#        1, 2, 2, 3, 3, 2, 2, 0, 2, 2, 1, 0, 2, 0, 2, 0, 2, 2, 3, 0, 2, 2,
#        3, 2, 2, 2, 3, 3, 1, 3, 2, 2, 2, 2, 3, 2, 0, 2, 3, 2, 2, 2, 2, 0,
#        0, 0, 3, 0, 1, 3, 2, 0, 3, 1, 0, 3, 2, 1, 3, 2, 2, 2, 2, 2, 1, 2,
#        3, 2, 2, 2, 2, 0, 1, 2, 3, 2, 2, 0, 3, 2, 3, 0, 0, 3, 2, 3, 3, 2,
#        0, 2, 0, 3, 2, 2, 2, 2, 0, 3, 0, 3, 3, 2, 3, 2, 0, 2, 3, 2, 0, 2,
#        2, 2, 2, 2, 3, 2, 0, 0, 0, 3, 3, 0, 2, 3, 2, 3, 2, 2, 3, 2, 1, 2,
#        1, 2, 1, 2, 2, 3, 0, 1, 2, 3, 2, 2, 3, 1, 3, 2, 2, 2, 3, 2, 2, 3,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 0, 3, 2, 0, 3, 1, 2, 2, 1, 2, 2, 2, 3,
#        0, 1, 3, 2, 0, 3, 3, 2, 3, 2, 3, 1, 3, 2, 2, 3, 2, 0, 2, 2, 2, 0,
#        3, 2, 0, 3, 2, 2, 3, 2, 0, 0, 2, 3, 2, 3, 0, 2, 2, 2, 3, 3, 2, 0,
#        3, 3, 2, 3, 2, 2, 3, 2, 2, 3, 1, 1, 2, 3, 3, 0, 2, 2, 0, 3, 2, 2,
#        0, 1, 3, 0, 2, 3, 3, 0, 0, 1, 0, 2, 2, 3, 2, 3, 3, 0, 2, 3, 0, 2,
#        2, 2, 2, 2, 3, 0, 0, 1, 2, 3, 3, 2, 0, 2, 2, 2, 2, 3, 3, 2, 2, 3,
#        2, 2, 2, 2, 3, 2, 3, 2, 0, 0, 2, 3, 1, 2, 2, 1, 0, 3, 3, 2, 0, 1,
#        2, 3, 2, 2, 2, 2, 3, 3, 3, 1, 1, 2, 3, 3, 2, 3, 3, 3, 0, 0, 2, 3,
#        2, 2, 2, 2, 2, 2, 2, 3, 2, 2, 1, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 3,
#        1, 0, 2, 0, 3, 2, 3, 1, 2, 2, 0, 3, 2, 1, 3, 2, 2, 2, 0, 2, 3, 2,
#        3, 0, 3, 1, 0, 2, 3, 2, 3, 2, 3, 2, 3, 0, 3, 3, 2, 3, 2, 2, 2, 2,
#        0, 0, 3, 1, 3, 0, 2, 2, 2, 3, 0, 3, 3, 2, 2, 3, 0, 3, 2, 2, 3, 0,
#        2, 2, 0, 3, 3, 1, 3, 2, 3, 2, 2, 2, 1, 2, 2, 2, 1, 1, 2, 2, 3, 2,
#        3, 2, 2, 2, 2, 0, 2])

# %% [markdown]
# # **EVALUACION**

# %%
from sklearn.metrics import classification_report, confusion_matrix
print (classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69        81
#            1       0.64      0.32      0.42       101
#            2       0.70      0.83      0.76       237
#            3       0.74      0.71      0.73       160
#
#     accuracy                           0.70       579
#    macro avg       0.68      0.65      0.65       579
# weighted avg       0.69      0.70      0.68       579

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
import matplotlib.pyplot as plt
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    Esta función imprime y marca la matriz de confusión.
    Se puede aplicar Normalización seteando la variable `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Matriz de confusión, sin normalización')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Etiqueta True')
    plt.xlabel('Etiqueta predecida')

# %%
# Computar la matriz de confusión
cnf_matrix = confusion_matrix(y_test, y_predict, labels=[0,1,2,3])
np.set_printoptions(precision=2)

print (classification_report(y_test, y_predict))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['angry:0','happy:1','Neutral:2','sad:3',],normalize= False,  title='Matriz de confusión')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69        81
#            1       0.64      0.32      0.42       101
#            2       0.70      0.83      0.76       237
#            3       0.74      0.71      0.73       160
#
#     accuracy                           0.70       579
#    macro avg       0.68      0.65      0.65       579
# weighted avg       0.69      0.70      0.68       579
#
# Matriz de confusión, sin normalización
# [[ 61   8  12   0]
#  [ 25  32  36   8]
#  [  6   3 196  32]
#  [  3   7  36 114]]
